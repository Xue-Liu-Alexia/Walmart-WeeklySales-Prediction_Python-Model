# %% [markdown]
# ![Data%20Mining%20Project%20%281%29.png](attachment:Data%20Mining%20Project%20%281%29.png)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Business-Problem" data-toc-modified-id="Business-Problem-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Business Problem</a></span><ul class="toc-item"><li><span><a href="#Introducing-the-Dataset" data-toc-modified-id="Introducing-the-Dataset-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introducing the Dataset</a></span></li><li><span><a href="#Data-Fields" data-toc-modified-id="Data-Fields-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Fields</a></span></li><li><span><a href="#Executive-Summary" data-toc-modified-id="Executive-Summary-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Executive Summary</a></span></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Importing-libraries" data-toc-modified-id="Importing-libraries-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importing libraries</a></span></li><li><span><a href="#Descriptive-Data" data-toc-modified-id="Descriptive-Data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Descriptive Data</a></span></li><li><span><a href="#Handling-Duplicate-Data" data-toc-modified-id="Handling-Duplicate-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Handling Duplicate Data</a></span></li><li><span><a href="#Handling-Missing-Values" data-toc-modified-id="Handling-Missing-Values-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Handling Missing Values</a></span></li><li><span><a href="#Handling-Outliers" data-toc-modified-id="Handling-Outliers-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Handling Outliers</a></span><ul class="toc-item"><li><span><a href="#Weekly_Sales" data-toc-modified-id="Weekly_Sales-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Weekly_Sales</a></span></li><li><span><a href="#Temperature" data-toc-modified-id="Temperature-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Temperature</a></span></li><li><span><a href="#Fuel_Price" data-toc-modified-id="Fuel_Price-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Fuel_Price</a></span></li><li><span><a href="#CPI" data-toc-modified-id="CPI-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>CPI</a></span></li><li><span><a href="#Unemployment" data-toc-modified-id="Unemployment-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>Unemployment</a></span></li></ul></li><li><span><a href="#Standardise-Values" data-toc-modified-id="Standardise-Values-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Standardise Values</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Correlation" data-toc-modified-id="Correlation-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Correlation</a></span></li><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Univariate Analysis</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Bivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Numeric---Categorical-Analysis" data-toc-modified-id="Numeric---Categorical-Analysis-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Numeric - Categorical Analysis</a></span><ul class="toc-item"><li><span><a href="#Weekly_Sales-VS-Store" data-toc-modified-id="Weekly_Sales-VS-Store-3.3.1.1"><span class="toc-item-num">3.3.1.1&nbsp;&nbsp;</span>Weekly_Sales VS Store</a></span></li><li><span><a href="#Weekly_Sales-VS-Date" data-toc-modified-id="Weekly_Sales-VS-Date-3.3.1.2"><span class="toc-item-num">3.3.1.2&nbsp;&nbsp;</span>Weekly_Sales VS Date</a></span></li><li><span><a href="#Weekly_Sales-VS-Holiday_Flag" data-toc-modified-id="Weekly_Sales-VS-Holiday_Flag-3.3.1.3"><span class="toc-item-num">3.3.1.3&nbsp;&nbsp;</span>Weekly_Sales VS Holiday_Flag</a></span></li></ul></li><li><span><a href="#Hypothesis-Testing" data-toc-modified-id="Hypothesis-Testing-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Hypothesis Testing</a></span><ul class="toc-item"><li><span><a href="#Normality-Test" data-toc-modified-id="Normality-Test-3.3.2.1"><span class="toc-item-num">3.3.2.1&nbsp;&nbsp;</span>Normality Test</a></span></li><li><span><a href="#Equal-Variances-Test" data-toc-modified-id="Equal-Variances-Test-3.3.2.2"><span class="toc-item-num">3.3.2.2&nbsp;&nbsp;</span>Equal Variances Test</a></span></li><li><span><a href="#Welch's-T-Test(Satterthwaite)" data-toc-modified-id="Welch's-T-Test(Satterthwaite)-3.3.2.3"><span class="toc-item-num">3.3.2.3&nbsp;&nbsp;</span>Welch's T-Test(Satterthwaite)</a></span></li><li><span><a href="#Fuel_Price-VS-Date" data-toc-modified-id="Fuel_Price-VS-Date-3.3.2.4"><span class="toc-item-num">3.3.2.4&nbsp;&nbsp;</span>Fuel_Price VS Date</a></span></li><li><span><a href="#CPI-VS-Date" data-toc-modified-id="CPI-VS-Date-3.3.2.5"><span class="toc-item-num">3.3.2.5&nbsp;&nbsp;</span>CPI VS Date</a></span></li><li><span><a href="#Unemployment-VS-Date" data-toc-modified-id="Unemployment-VS-Date-3.3.2.6"><span class="toc-item-num">3.3.2.6&nbsp;&nbsp;</span>Unemployment VS Date</a></span></li><li><span><a href="#Fuel_Price-VS-Store" data-toc-modified-id="Fuel_Price-VS-Store-3.3.2.7"><span class="toc-item-num">3.3.2.7&nbsp;&nbsp;</span>Fuel_Price VS Store</a></span></li><li><span><a href="#Unemployment-VS-Store" data-toc-modified-id="Unemployment-VS-Store-3.3.2.8"><span class="toc-item-num">3.3.2.8&nbsp;&nbsp;</span>Unemployment VS Store</a></span></li><li><span><a href="#Fuel_Price-VS-Holiday_Flag" data-toc-modified-id="Fuel_Price-VS-Holiday_Flag-3.3.2.9"><span class="toc-item-num">3.3.2.9&nbsp;&nbsp;</span>Fuel_Price VS Holiday_Flag</a></span></li><li><span><a href="#CPI-VS-Holiday_Flag" data-toc-modified-id="CPI-VS-Holiday_Flag-3.3.2.10"><span class="toc-item-num">3.3.2.10&nbsp;&nbsp;</span>CPI VS Holiday_Flag</a></span></li></ul></li><li><span><a href="#Numeric---Numeric-Analysis" data-toc-modified-id="Numeric---Numeric-Analysis-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Numeric - Numeric Analysis</a></span><ul class="toc-item"><li><span><a href="#Weekly_Sales-VS-Temperature" data-toc-modified-id="Weekly_Sales-VS-Temperature-3.3.3.1"><span class="toc-item-num">3.3.3.1&nbsp;&nbsp;</span>Weekly_Sales VS Temperature</a></span></li><li><span><a href="#Weekly_Sales-VS-Fuel_Price" data-toc-modified-id="Weekly_Sales-VS-Fuel_Price-3.3.3.2"><span class="toc-item-num">3.3.3.2&nbsp;&nbsp;</span>Weekly_Sales VS Fuel_Price</a></span></li><li><span><a href="#Weekly_Sales-VS-CPI" data-toc-modified-id="Weekly_Sales-VS-CPI-3.3.3.3"><span class="toc-item-num">3.3.3.3&nbsp;&nbsp;</span>Weekly_Sales VS CPI</a></span></li><li><span><a href="#Weekly_Sales-VS-Unemployment" data-toc-modified-id="Weekly_Sales-VS-Unemployment-3.3.3.4"><span class="toc-item-num">3.3.3.4&nbsp;&nbsp;</span>Weekly_Sales VS Unemployment</a></span></li><li><span><a href="#Fuel_Price-VS-Temperature" data-toc-modified-id="Fuel_Price-VS-Temperature-3.3.3.5"><span class="toc-item-num">3.3.3.5&nbsp;&nbsp;</span>Fuel_Price VS Temperature</a></span></li><li><span><a href="#CPI-VS-Fuel_Price" data-toc-modified-id="CPI-VS-Fuel_Price-3.3.3.6"><span class="toc-item-num">3.3.3.6&nbsp;&nbsp;</span>CPI VS Fuel_Price</a></span></li><li><span><a href="#CPI-VS-Temperature" data-toc-modified-id="CPI-VS-Temperature-3.3.3.7"><span class="toc-item-num">3.3.3.7&nbsp;&nbsp;</span>CPI VS Temperature</a></span></li><li><span><a href="#CPI-VS-Unemployment" data-toc-modified-id="CPI-VS-Unemployment-3.3.3.8"><span class="toc-item-num">3.3.3.8&nbsp;&nbsp;</span>CPI VS Unemployment</a></span></li></ul></li></ul></li><li><span><a href="#Multivariate-Analysis" data-toc-modified-id="Multivariate-Analysis-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Multivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Regression-Test" data-toc-modified-id="Regression-Test-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Regression Test</a></span></li></ul></li></ul></li><li><span><a href="#Feature-Selection-/-Engineering" data-toc-modified-id="Feature-Selection-/-Engineering-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Feature Selection / Engineering</a></span><ul class="toc-item"><li><span><a href="#Handling-Outlier:-LOF" data-toc-modified-id="Handling-Outlier:-LOF-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Handling Outlier: LOF</a></span></li><li><span><a href="#Scale-Data" data-toc-modified-id="Scale-Data-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Scale Data</a></span></li><li><span><a href="#Remove-Collinear-Features" data-toc-modified-id="Remove-Collinear-Features-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Remove Collinear Features</a></span></li><li><span><a href="#Check-VIF-score" data-toc-modified-id="Check-VIF-score-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Check VIF score</a></span></li></ul></li><li><span><a href="#Model-Selection" data-toc-modified-id="Model-Selection-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model Selection</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Split-Data" data-toc-modified-id="Split-Data-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Split Data</a></span></li><li><span><a href="#Regularization" data-toc-modified-id="Regularization-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Regularization</a></span><ul class="toc-item"><li><span><a href="#Ridge-Regression" data-toc-modified-id="Ridge-Regression-5.1.2.1"><span class="toc-item-num">5.1.2.1&nbsp;&nbsp;</span>Ridge Regression</a></span></li><li><span><a href="#Lasso-Regression" data-toc-modified-id="Lasso-Regression-5.1.2.2"><span class="toc-item-num">5.1.2.2&nbsp;&nbsp;</span>Lasso Regression</a></span></li></ul></li><li><span><a href="#Testing-Multiple&nbsp;Linear-Regression-Assumptions" data-toc-modified-id="Testing-Multiple&nbsp;Linear-Regression-Assumptions-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Testing Multiple&nbsp;Linear Regression Assumptions</a></span><ul class="toc-item"><li><span><a href="#Linearity-Assumption" data-toc-modified-id="Linearity-Assumption-5.1.3.1"><span class="toc-item-num">5.1.3.1&nbsp;&nbsp;</span>Linearity Assumption</a></span></li><li><span><a href="#No-Multicollinearity-among-Predictors" data-toc-modified-id="No-Multicollinearity-among-Predictors-5.1.3.2"><span class="toc-item-num">5.1.3.2&nbsp;&nbsp;</span>No Multicollinearity among Predictors</a></span></li><li><span><a href="#Normality-of-the-Error-Terms" data-toc-modified-id="Normality-of-the-Error-Terms-5.1.3.3"><span class="toc-item-num">5.1.3.3&nbsp;&nbsp;</span>Normality of the Error Terms</a></span></li><li><span><a href="#Homoscedasticity" data-toc-modified-id="Homoscedasticity-5.1.3.4"><span class="toc-item-num">5.1.3.4&nbsp;&nbsp;</span>Homoscedasticity</a></span></li><li><span><a href="#No-Autocorrelation-of-the-Error-Terms" data-toc-modified-id="No-Autocorrelation-of-the-Error-Terms-5.1.3.5"><span class="toc-item-num">5.1.3.5&nbsp;&nbsp;</span>No Autocorrelation of the Error Terms</a></span></li></ul></li></ul></li><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Random Forest</a></span></li></ul></li><li><span><a href="#Model-Training" data-toc-modified-id="Model-Training-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Training</a></span></li><li><span><a href="#Pattern-Discovery" data-toc-modified-id="Pattern-Discovery-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Pattern Discovery</a></span></li><li><span><a href="#Model-Evaluation" data-toc-modified-id="Model-Evaluation-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model Evaluation</a></span><ul class="toc-item"><li><span><a href="#Cross-validation" data-toc-modified-id="Cross-validation-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Cross validation</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Feature Importance</a></span></li></ul></li><li><span><a href="#Interpretation-and-Application" data-toc-modified-id="Interpretation-and-Application-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Interpretation and Application</a></span></li></ul></div>

# %% [markdown]
# # Business Problem

# %% [markdown]
# **Define the business problem that you are trying to solve. <br>What is the business context and what are the constraints you might face.**

# %% [markdown]
# ## Introducing the Dataset

# %% [markdown]
# Walmart Inc. is an American multinational retail corporation that operates a chain of hypermarkets (also called supercenters), discount department stores, and grocery stores in the United States, headquartered in Bentonville, Arkansas. The company was founded by Sam Walton in nearby Rogers, Arkansas in 1962 and incorporated under Delaware General Corporation Law on October 31, 1969. It also owns and operates Sam's Club retail warehouses.<br>
# <br>
# Walmart is the world's largest company by revenue, with about US $570 billion in annual revenue, according to the Fortune Global 500 list in May 2022.<br>
# <br>
# As of July 31, 2022, Walmart has 10,585 stores and clubs in 24 countries, operating under 46 different names. Out of which I have chosen 45 stores for basic analysis.

# %% [markdown]
# ## Data Fields

# %% [markdown]
# - **Store**: Store Numbers ranging from 1 to 45.
# - **Date**: The Week of Sales. It is in the format of dd-mm-yyyy. The date starts from 05-02-2010.
# - **Weekly_Sales**: The sales of the given store in the given week.
# - **Holiday_Flag**: If the week has a special Holiday or not. 1-The week has a Holiday 0-Fully working week Holiday events is given in.
# - **Temperature**: Average Temperature of the week of sales.
# - **Fuel_Price**: Price of the Fuel in the region of the given store.
# - **CPI**: Customer Price Index.
# - **Unemployment**: Unemployment of the given store region.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# - 1. About the relationship between holidays and weekly sales
# If there is a memorable holiday in a week, then the weekly sales this week are higher than on working days.<br>
# On weeks with holidays, fuel prices will be lower than on weeks without holidays.<br>
# Sales every winter, especially from Black Friday to Christmas, are much higher than during other holidays and other working days.<br>
# During major annual holidays such as Black Friday and Christmas, gas prices are lower than usual and stores offer deep discounts, stimulating consumption.<br>
# Therefore, Black Friday and Christmas should be the focus of the year-round marketing strategy every year, and the proportion of attention should be much higher than during Labor Day and the super boul period.
#
# - 2. About the relationship between CPI and weekly sales
# An increase in the CPI index will increase store sales. At this time, discounts should be increased, promotion methods should be increased, and advertising should be increased.<br>
# When fuel prices are too high, the CPI index will drop rapidly.<br>
# When the temperature is too high or too low, the CPI index will drop rapidly.<br>
# When the unemployment rate is too high, the CPI index will drop rapidly, and store sales will also drop sharply. At this time, marketing strategies and advertising should be slowed down.
#
# - 3. About the relationship between unemployment rates and weekly sales
# The stores in the three regions with the highest unemployment rates are #12, #28, #38.<br>
# The stores in the two regions with the lowest unemployment rates are #23 and #40.<br>
# The weekly sales of the three stores with the highest unemployment rate are not in the top ten of weekly sales, but the weekly sales of the two stores with the lowest unemployment rate are not in the top ten of weekly sales either.<br>
# It proves that a higher unemployment rate may affect store sales, but this impact is relatively small and not a major influencing factor.<br>
#
# - 4. About the relationship between temperature and weekly sales
# Temperatures between 60℉ and 80℉ degrees are most frequent.<br>
# Higher store sales occur when the temperature is 20℉ to 60℉.<br>
# When the temperature is less than 20℉ or higher than 90℉, store sales are generally lower.<br>
# Extreme weather means that store sales are not high. If you want to maintain normal sales at this time, you should increase discounts and change your market strategy.<br>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Cleaning, transforming, and preparing the data for analysis. <br>This step includes handling missing values, dealing with outliers, and ensuring data quality.**

# %% [markdown]
# ## Importing libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime
import scipy.stats as stats
from statsmodels.formula.api import ols

import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.neighbors import LocalOutlierFactor
from sklearn.feature_selection import RFE

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Descriptive Data

# %%
df= pd.read_csv('walmart-sales-dataset-of-45stores.csv')
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df.shape
# Out:
# (6435, 8)

# %% [markdown]
# ## Handling Duplicate Data

# %%
df_nodub=df.drop_duplicates() 
print(df.shape,df_nodub.shape,'\n Number of duplicate data : ',df.shape[0]-df_nodub.shape[0])
# Out:
# (6435, 8) (6435, 8)
#  Number of duplicate data :  0

# %% [markdown]
# **There is no duplicate data.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
pd.options.display.float_format = "{:.2f}".format
df.describe()
# Out:
#         Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price     CPI  \
# count 6435.00       6435.00       6435.00      6435.00     6435.00 6435.00
# mean    23.00    1046964.88          0.07        60.66        3.36  171.58
# std     12.99     564366.62          0.26        18.44        0.46   39.36
# min      1.00     209986.25          0.00        -2.06        2.47  126.06
# 25%     12.00     553350.10          0.00        47.46        2.93  131.74
# 50%     23.00     960746.04          0.00        62.67        3.44  182.62
# 75%     34.00    1420158.66          0.00        74.94        3.73  212.74
# max     45.00    3818686.45          1.00       100.14        4.47  227.23
#
#        Unemployment
# count       6435.00
# mean           8.00
# std            1.88
# min            3.88
# 25%            6.89
# 50%            7.87
# 75%            8.62
# max           14.31

# %%
df.astype('object').describe().transpose()
# Out:
#                count  unique         top  freq
# Store           6435      45           1   143
# Date            6435     143  05-02-2010    45
# Weekly_Sales 6435.00 6435.00  1643690.90  1.00
# Holiday_Flag    6435       2           0  5985
# Temperature  6435.00 3528.00       50.43 11.00
# Fuel_Price   6435.00  892.00        3.64 39.00
# CPI          6435.00 2145.00      130.55 11.00
# Unemployment 6435.00  349.00        8.10 78.00

# %%
df.Holiday_Flag.value_counts(dropna = False) # 1-The week has a Holiday, 0-The week no Holiday
# Out:
# 0    5985
# 1     450
# Name: Holiday_Flag, dtype: int64

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# **There is no missing value**

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# ### Weekly_Sales

# %%
df.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
plt.figure(figsize = (4,4))
sns.boxplot(df.Weekly_Sales)
plt.show()

# %%
df.Weekly_Sales.describe()
# Out:
# count      6435.00
# mean    1046964.88
# std      564366.62
# min      209986.25
# 25%      553350.10
# 50%      960746.04
# 75%     1420158.66
# max     3818686.45
# Name: Weekly_Sales, dtype: float64

# %%
np.percentile(df.Weekly_Sales,[0,1,5,25,50])
# Out:
# array([209986.25  , 253103.0686, 308426.689 , 553350.105 , 960746.04  ])

# %%
np.percentile(df.Weekly_Sales,[50,75,95,99,100])
# Out:
# array([ 960746.04 , 1420158.66 , 2049178.512, 2404035.305, 3818686.45 ])

# %%
IQR = 1420158.66 - 553350.105 # IQR = value(Q3）-value(Q1)
IQR
# Out:
# 866808.5549999999

# %%
1420158.66 + 1.5* IQR # Upper inner fence: Q3 + 1.5*IQR
# Out:
# 2720371.4924999997

# %%
1420158.66 + 3* IQR # Upper outer fence: Q3 + 3*IQR
# Out:
# 4020584.325

# %%
df[~(df.Weekly_Sales>2720371.4924999997)].Weekly_Sales.describe()
# Out:
# count      6401.00
# mean    1036130.35
# std      545196.06
# min      209986.25
# 25%      551743.05
# 50%      957298.26
# 75%     1414564.53
# max     2685351.81
# Name: Weekly_Sales, dtype: float64

# %%
df[df.Weekly_Sales>2720371.4924999997].Weekly_Sales.describe() # Check possible outliers
# Out:
# count        34.00
# mean    3086723.36
# std      379436.72
# min     2727575.18
# 25%     2767649.33
# 50%     2913971.48
# 75%     3474992.09
# max     3818686.45
# Name: Weekly_Sales, dtype: float64

# %%
df[df.Weekly_Sales>4020584.325].Weekly_Sales.describe() # Check extreme outliers
# Out:
# count   0.00
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# **There are 34 possible outliers, but no extreme outliers and no significant gap between the fence and potential outliers and there are continuous values that make sense, so I leave it as typical high values.**

# %% [markdown]
# ### Temperature

# %%
plt.figure(figsize = (4,4))
sns.boxplot(df.Temperature)
plt.show()

# %%
np.percentile(df.Temperature,[0,1,5,25,50])
# Out:
# array([-2.06  , 18.5236, 27.73  , 47.46  , 62.67  ])

# %%
np.percentile(df.Temperature,[50,75,95,99,100])
# Out:
# array([ 62.67 ,  74.94 ,  87.663,  93.19 , 100.14 ])

# %%
IQR = 74.94 - 47.46 # IQR = value(Q3）-value(Q1)
IQR
# Out:
# 27.479999999999997

# %%
47.46 - 1.5* IQR # Lower inner fence: Q1 - 1.5*IQR
# Out:
# 6.240000000000002

# %%
47.46 - 3* IQR # Lower outer fence: Q1 - 3*IQR
# Out:
# -34.98

# %%
df.Temperature.describe() # 2.06℉= -16.63333℃， 100.14℉= 37.85556℃
# Out:
# count   6435.00
# mean      60.66
# std       18.44
# min       -2.06
# 25%       47.46
# 50%       62.67
# 75%       74.94
# max      100.14
# Name: Temperature, dtype: float64

# %%
df[~(df.Temperature<6.240000000000002)].Temperature.describe()
# Out:
# count   6432.00
# mean      60.69
# std       18.41
# min        7.46
# 25%       47.51
# 50%       62.68
# 75%       74.95
# max      100.14
# Name: Temperature, dtype: float64

# %%
df[df.Temperature<6.240000000000002].Temperature.describe() # Check possible outliers
# Out:
# count    3.00
# mean     3.24
# std      4.60
# min     -2.06
# 25%      1.74
# 50%      5.54
# 75%      5.88
# max      6.23
# Name: Temperature, dtype: float64

# %%
df[df.Temperature<-34.98].Temperature.describe() # Check extreme outliers
# Out:
# count   0.00
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Temperature, dtype: float64

# %% [markdown]
# **There are 3 possible outliers, but no extreme outliers and no significant gap between the fence and potential outliers and there are continuous values that make sense, so I leave it as typical low values.**

# %% [markdown]
# ### Fuel_Price

# %%
plt.figure(figsize = (4,4))
sns.boxplot(df.Fuel_Price)
plt.show()

# %% [markdown]
# **There are no outliers.**

# %% [markdown]
# ### CPI

# %%
plt.figure(figsize = (4,4))
sns.boxplot(df.CPI)
plt.show()

# %% [markdown]
# **There are no outliers.**

# %% [markdown]
# ### Unemployment

# %%
plt.figure(figsize = (4,4))
sns.boxplot(df.Unemployment)
plt.show()

# %%
np.percentile(df.Unemployment,[0,1,5,25,50])
# Out:
# array([3.879, 4.156, 5.326, 6.891, 7.874])

# %%
np.percentile(df.Unemployment,[50,75,95,99,100])
# Out:
# array([ 7.874,  8.622, 12.187, 14.18 , 14.313])

# %%
IQR = 8.622 - 6.891 # IQR = value(Q3）-value(Q1)
IQR
# Out:
# 1.7309999999999999

# %%
8.622 + 1.5* IQR # Upper inner fence: Q3 + 1.5*IQR
# Out:
# 11.218499999999999

# %%
8.622 + 3* IQR # Upper outer fence: Q3 + 3*IQR
# Out:
# 13.815

# %%
6.891 - 1.5* IQR # Lower inner fence: Q1 - 1.5*IQR
# Out:
# 4.2945

# %%
6.891 - 3* IQR # Lower outer fence: Q1 - 3*IQR
# Out:
# 1.6980000000000004

# %%
df.Unemployment.describe()
# Out:
# count   6435.00
# mean       8.00
# std        1.88
# min        3.88
# 25%        6.89
# 50%        7.87
# 75%        8.62
# max       14.31
# Name: Unemployment, dtype: float64

# %%
df[~(df.Unemployment>11.218499999999999)].Unemployment.describe() # Upper outliers
# Out:
# count   6057.00
# mean       7.66
# std        1.32
# min        3.88
# 25%        6.87
# 50%        7.83
# 75%        8.48
# max       10.93
# Name: Unemployment, dtype: float64

# %%
df[~(df.Unemployment>13.815)].Unemployment.describe()
# Out:
# count   6255.00
# mean       7.82
# std        1.58
# min        3.88
# 25%        6.89
# 50%        7.86
# 75%        8.54
# max       13.74
# Name: Unemployment, dtype: float64

# %%
df[df.Unemployment>11.218499999999999].Unemployment.describe() # Check possible outliers
# Out:
# count   378.00
# mean     13.44
# std       0.88
# min      11.63
# 25%      12.89
# 50%      13.74
# 75%      14.10
# max      14.31
# Name: Unemployment, dtype: float64

# %%
df[df.Unemployment>13.815].Unemployment.describe() # Check extreme outliers
# Out:
# count   180.00
# mean     14.13
# std       0.12
# min      13.97
# 25%      14.02
# 50%      14.10
# 75%      14.18
# max      14.31
# Name: Unemployment, dtype: float64

# %%
df[~(df.Unemployment<4.2945)].Unemployment.describe() # Lower outliers
# Out:
# count   6332.00
# mean       8.06
# std        1.83
# min        4.31
# 25%        6.94
# 50%        7.91
# 75%        8.62
# max       14.31
# Name: Unemployment, dtype: float64

# %%
df[df.Unemployment<4.2945].Unemployment.describe() # Check possible outliers
# Out:
# count   103.00
# mean      4.15
# std       0.08
# min       3.88
# 25%       4.12
# 50%       4.16
# 75%       4.21
# max       4.26
# Name: Unemployment, dtype: float64

# %%
df[df.Unemployment<1.6980000000000004].Unemployment.describe() # Check extreme outliers
# Out:
# count   0.00
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Unemployment, dtype: float64

# %% [markdown]
# **After searching the information online, I found that the unemployment rate has fluctuated between 3% and 15% in the past 20 years. <br>These outliers are within the normal range.So I decided to keep them.**

# %% [markdown]
# ## Standardise Values

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%d-%m-%Y')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# **Exploring the data visually and statistically to gain a better understanding of its characteristics and relationships.**

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(), annot=True, cmap="Reds")
# Out:
# <Axes: >

# %% [markdown]
# ## Univariate Analysis

# %%
df.Holiday_Flag.value_counts(normalize=True)*100
# Out:
# 0   93.01
# 1    6.99
# Name: Holiday_Flag, dtype: float64

# %%
plt.figure(figsize = (4,4))
sns.barplot(x=df['Holiday_Flag'].value_counts(normalize=True).index, y=df['Holiday_Flag'].value_counts(normalize=True)*100)
plt.show()

# %%
plt.figure(figsize = (4,4))
sns.set_style("white")
sns.distplot(df.Weekly_Sales, bins=20)
plt.show()

# %%
plt.figure(figsize = (4,4))
sns.set_style("white")
sns.distplot(df.Temperature, bins=20)
plt.show()

# %% [markdown]
# **Temperatures between 60℉ and 80℉ degrees are most frequent.**

# %%
plt.figure(figsize = (4,4))
sns.distplot(df.Fuel_Price, bins=20, color="g")
plt.show()

# %% [markdown]
# F**uel prices are mainly concentrated between 3.5 and 4.**

# %%
plt.figure(figsize = (4,4))
sns.distplot(df.CPI, bins=20, color="b")
plt.show()

# %% [markdown]
# **The frequency of CPI between 125 and 130 is significantly higher than many others.**

# %%
plt.figure(figsize = (4,4))
sns.set_style("white")
sns.distplot(df.Unemployment, bins=20, color="r")
plt.show()

# %% [markdown]
# **Unemployment rate are mainly concentrated between 7 and 9.**

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numeric - Categorical Analysis

# %% [markdown]
# #### Weekly_Sales VS Store

# %%
plt.figure(figsize = (10,4))
sns.barplot(df, x='Store', y='Weekly_Sales')
plt.show()

# %% [markdown]
# **The top 5 stores by weekly sales are: #20, #4, #14, #13, #2.<br>
# The bottom 5 stores by weekly sales are: #33, #44, #5, #36, #38.**

# %% [markdown]
# #### Weekly_Sales VS Date

# %%
df.groupby('Date')[['Weekly_Sales']].sum().plot()
plt.show()

# %% [markdown]
# **Sales every winter, especially from Black Friday to Christmas, are much higher than during other holidays and other working days.**

# %% [markdown]
# #### Weekly_Sales VS Holiday_Flag

# %%
plt.figure(figsize = (4,3))
sns.barplot(df, x='Holiday_Flag', y='Weekly_Sales')
plt.show()

# %% [markdown]
# **If there is a memorable holiday in a week, then the weekly sales this week are higher than on working days.**

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# **Business Problem: <br>
# Is there a significant difference between the weekly sales of the week with holidays and the week without holidays?<br>
# Is this difference in the mean statistically significant or it just due to random chance?<br>
# <br>
# H0: There have no significant difference between the weekly sales of the week with holidays and the week without holidays.**

# %% [markdown]
# #### Normality Test

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31        2.57
# 1      1 2010-02-12    1641957.44             1        38.51        2.55
# 2      1 2010-02-19    1611968.17             0        39.93        2.51
# 3      1 2010-02-26    1409727.59             0        46.63        2.56
# 4      1 2010-03-05    1554806.68             0        46.50        2.62
#
#      CPI  Unemployment
# 0 211.10          8.11
# 1 211.24          8.11
# 2 211.29          8.11
# 3 211.32          8.11
# 4 211.35          8.11

# %%
x=df[df["Holiday_Flag"]==0]['Weekly_Sales']
y=df[df["Holiday_Flag"]==1]['Weekly_Sales']

# %%
import scipy.stats as stats
stats.shapiro(x)
# Out:
# ShapiroResult(statistic=0.946863055229187, pvalue=5.025056293068794e-42)

# %%
stats.shapiro(y)
# Out:
# ShapiroResult(statistic=0.9449769258499146, pvalue=7.148078136343106e-12)

# %% [markdown]
# **Since p-values are less than 0.05, I can to reject the null hypothesis and conclude that these two groups are not normally distributed.<br>
# Since the sample size is large enough (≥30). I can rely on the Central Limit Theorem.**

# %% [markdown]
# #### Equal Variances Test

# %%
stats.levene(x,y)
# Out:
# LeveneResult(statistic=10.519203649624915, pvalue=0.0011874337918717478)

# %% [markdown]
# **Since p-value=0.0012 is less than 0.05, I can to reject the null hypothesis and conclude that these two groups have significant difference in their variances.<br>
# So choose Welch's T-Test(Satterthwaite).**

# %% [markdown]
# #### Welch's T-Test(Satterthwaite)

# %%
stats.ttest_ind(x,y, equal_var=False)
# Out:
# Ttest_indResult(statistic=-2.6800720209265423, pvalue=0.007601552012134143)

# %% [markdown]
# **Since p-value=0.0076 is less than 0.05, I can to reject the null hypothesis and conclude that there have significant difference between the weekly sales of the week with holidays and the week without holidays.<br>
# Same as the plot shows, If there is a memorable holiday in a week, then the weekly sales this week are higher than on working days.**

# %% [markdown]
# #### Fuel_Price VS Date

# %%
df.groupby('Date')[['Fuel_Price']].sum().plot()
plt.show()

# %% [markdown]
# **Oil prices have shown an overall upward trend over time. <br>
# It accelerated from January 2011 and fell back in May 2011. Half a year later, in January 2012, it accelerated again and fell again in May.<br>
# Generally speaking, oil prices will rise rapidly starting from January every year and will fall back in May, but the overall price is on an upward trend every year.**

# %% [markdown]
# #### CPI VS Date

# %%
df.groupby('Date')[['CPI']].sum().plot()
plt.show()

# %% [markdown]
# **As time goes by, the CPI (Customer Price Index) generally shows an upward trend.<br>
# When oil prices rise rapidly, the CPI also rises rapidly. When oil prices fall or rise slowly, the CPI rises slowly.
# <br>
# The rapid rise in oil prices may stimulate the economy and accelerate the rise in the CPI.**

# %% [markdown]
# #### Unemployment VS Date

# %%
df.groupby('Date')[['Unemployment']].sum().plot()
plt.show()

# %% [markdown]
# **Over time, the unemployment rate continues to decline, possibly because economic development continues to rise.<br>
# At the same time, the CPI continues to rise, possibly because the economy is rising, and the unemployment rate continues to decline, both of which will indirectly lead to the CPI rising.**

# %% [markdown]
# #### Fuel_Price VS Store

# %%
plt.figure(figsize = (10,4))
sns.barplot(df, x='Store', y='Fuel_Price')
plt.show()

# %% [markdown]
# **There is not much difference in fuel prices between stores.**

# %% [markdown]
# #### Unemployment VS Store

# %%
plt.figure(figsize = (10,4))
sns.barplot(df, x='Store', y='Unemployment')
plt.show()

# %% [markdown]
# **The stores in the three regions with the highest unemployment rates are #12, #28, #38. <br>
# The stores in the two regions with the lowest unemployment rates are #23 and #40. <br>
# The weekly sales of the three stores with the highest unemployment rate are not in the top ten of weekly sales, but the weekly sales of the two stores with the lowest unemployment rate are not in the top ten of weekly sales either.<br>
# It proves that a higher unemployment rate may affect store sales, but this impact is relatively small and not a major influencing factor.**

# %% [markdown]
# #### Fuel_Price VS Holiday_Flag

# %%
plt.figure(figsize = (4,4))
sns.barplot(df, x='Holiday_Flag', y='Fuel_Price')
plt.show()

# %% [markdown]
# **On weeks with holidays, fuel prices will be lower than on weeks without holidays.**

# %% [markdown]
# #### CPI VS Holiday_Flag

# %%
plt.figure(figsize = (4,4))
sns.barplot(df, x='Holiday_Flag', y='CPI')
plt.show()

# %% [markdown]
# **Weeks with or without holidays will not affect the CPI.**

# %% [markdown]
# ### Numeric - Numeric Analysis

# %% [markdown]
# #### Weekly_Sales VS Temperature

# %%
plt.figure(figsize = (4,4))
sns.set_style("white")
sns.distplot(df.Temperature, bins=20)
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Temperature', y='Weekly_Sales')
plt.show()

# %% [markdown]
# **Temperatures between 60℉ and 80℉ degrees are most frequent.<br>
# Higher store sales occur when the temperature is 20℉ to 60℉. <br>
# When the temperature is less than 20℉ or higher than 90℉, store sales are generally lower.**

# %% [markdown]
# #### Weekly_Sales VS Fuel_Price

# %%
plt.figure(figsize = (4,4))
sns.distplot(df.Fuel_Price, bins=20, color="g")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Fuel_Price', y='Weekly_Sales')
plt.show()

# %% [markdown]
# **Fuel prices are mainly concentrated between 3.5 and 4.<br>
# Higher store sales occur when the fuel price is 2.8 to 3.5, around the mean(3.36). <br>
# Lower fuel prices do not lead to more sales, but higher fuel prices lead to lower sales.<br>
# It proves that lower fuel prices will drive up sales. However, when fuel prices are too low, far below the average of 3.36, it may be because of poor economic conditions or other factors that affect sales.<br>
# However, excessively high fuel prices will significantly reduce sales.**

# %% [markdown]
# #### Weekly_Sales VS CPI

# %%
plt.figure(figsize = (4,4))
sns.distplot(df.CPI, bins=20, color="b")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='CPI', y='Weekly_Sales')
plt.show()

# %% [markdown]
# **An increase in the CPI index will increase store sales.**

# %% [markdown]
# #### Weekly_Sales VS Unemployment

# %%
plt.figure(figsize = (4,4))
sns.set_style("white")
sns.distplot(df.Unemployment, bins=20, color="r")
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Unemployment', y='Weekly_Sales')
plt.show()

# %% [markdown]
# **Lower unemployment rate increases sales. When unemployment rate is high, store sales drop sharply.**

# %% [markdown]
# #### Fuel_Price VS Temperature

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Temperature', y='Fuel_Price')
plt.show()

# %% [markdown]
# **Fuel prices may increase as temperatures rise.<br>
# Fuel prices in summer are generally higher than in winter.**

# %% [markdown]
# #### CPI VS Fuel_Price

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Fuel_Price', y='CPI')
plt.show()

# %% [markdown]
# **When fuel prices are too high, the CPI index will drop rapidly.**

# %% [markdown]
# #### CPI VS Temperature

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Temperature', y='CPI')
plt.show()

# %% [markdown]
# **When the temperature is too high or too low, the CPI index will drop rapidly.**

# %% [markdown]
# #### CPI VS Unemployment

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(data=df, x='Unemployment', y='CPI')
plt.show()

# %% [markdown]
# **When the unemployment rate is too high, the CPI index will drop rapidly.**

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Regression Test

# %% [markdown]
# **Business Problem: <br>
# Is there a significant relationship between the store, holiday and the weekly sales?<br>
# <br>
# H0: There have no significant relationship between them.**

# %%
from statsmodels.formula.api import ols
model = ols('Weekly_Sales ~ C(Store) * C(Holiday_Flag)',df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Weekly_Sales   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     813.4
# Date:                Sun, 10 Sep 2023   Prob (F-statistic):               0.00
# Time:                        19:27:19   Log-Likelihood:                -86249.
# No. Observations:                6435   AIC:                         1.727e+05
# Df Residuals:                    6345   BIC:                         1.733e+05
# Df Model:                          89
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Since p-value is less than 0.05, I can to reject the null hypothesis and conclude that there have a significant relationship between them.<br>
# <br>
# The weekly sales of each store will differ depending on whether the week contains holidays.**

# %% [markdown]
# # Feature Selection / Engineering

# %% [markdown]
# **Choosing or creating the most relevant and informative features (variables) that will be used in the analysis.**

# %%
df_copy1=df.copy()

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31        2.57
# 1      1 2010-02-12    1641957.44             1        38.51        2.55
# 2      1 2010-02-19    1611968.17             0        39.93        2.51
# 3      1 2010-02-26    1409727.59             0        46.63        2.56
# 4      1 2010-03-05    1554806.68             0        46.50        2.62
#
#      CPI  Unemployment
# 0 211.10          8.11
# 1 211.24          8.11
# 2 211.29          8.11
# 3 211.32          8.11
# 4 211.35          8.11

# %%
df['Date'] = (df['Date'] - pd.Timestamp("1970-01-01")) // pd.Timedelta(days=1)
df.head()
# Out:
#    Store   Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price    CPI  \
# 0      1  14645    1643690.90             0        42.31        2.57 211.10
# 1      1  14652    1641957.44             1        38.51        2.55 211.24
# 2      1  14659    1611968.17             0        39.93        2.51 211.29
# 3      1  14666    1409727.59             0        46.63        2.56 211.32
# 4      1  14673    1554806.68             0        46.50        2.62 211.35
#
#    Unemployment
# 0          8.11
# 1          8.11
# 2          8.11
# 3          8.11
# 4          8.11

# %%
df.shape
# Out:
# (6435, 8)

# %% [markdown]
# ## Handling Outlier: LOF

# %%
df_copy2=df.copy()

# %%
X = df.drop("Weekly_Sales",axis=1)
y = df["Weekly_Sales"]

# %%
from sklearn.neighbors import LocalOutlierFactor
lof=LocalOutlierFactor(n_neighbors=5)
res=lof.fit_predict(X)
X=X[res !=-1]
y=y[res !=-1]

# %%
df = pd.concat([X, y], axis=1)
df.shape
# Out:
# (6431, 8)

# %% [markdown]
# ## Scale Data

# %%
df_copy3=df.copy()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() 
df = pd.DataFrame(sc.fit_transform(df),columns = df.columns)

# %% [markdown]
# ## Remove Collinear Features

# %%
df_copy4=df.copy()

# %%
X = df.drop("Weekly_Sales",axis=1)
y = df["Weekly_Sales"]

# %%
def remove_collinear_features(df,label, threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model
        to generalize and improves the interpretability of the model.
        
    Inputs: 
        threshold: any features with correlations greater than this value are removed
    
    Output: 
        dataframe that contains only the non-highly-collinear features
    '''
    # Dont want to remove correlations between label and features
    y = df[label]
    df.drop(columns = [label],inplace=True)
    
    # Calculate the correlation matrix
    corr_matrix = df.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)
            
            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
                print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    df = df.drop(columns = drops)
    
    # Add the score back in to the data
    df[label] = y
               
    return df

# %%
df.corr()
# Out:
#               Store  Date  Holiday_Flag  Temperature  Fuel_Price   CPI  \
# Store          1.00 -0.00          0.00        -0.02        0.06 -0.21
# Date          -0.00  1.00         -0.01         0.14        0.77  0.08
# Holiday_Flag   0.00 -0.01          1.00        -0.16       -0.08 -0.00
# Temperature   -0.02  0.14         -0.16         1.00        0.14  0.18
# Fuel_Price     0.06  0.77         -0.08         0.14        1.00 -0.17
# CPI           -0.21  0.08         -0.00         0.18       -0.17  1.00
# Unemployment   0.22 -0.25          0.01         0.10       -0.04 -0.30
# Weekly_Sales  -0.34  0.01          0.04        -0.06        0.01 -0.07
#
#               Unemployment  Weekly_Sales
# Store                 0.22         -0.34
# Date                 -0.25          0.01
# Holiday_Flag          0.01          0.04
# Temperature           0.10         -0.06
# Fuel_Price           -0.04          0.01
# CPI                  -0.30         -0.07
# ...

# %%
df = remove_collinear_features(df,"Weekly_Sales" ,0.60)
# Out:
# Fuel_Price | Date | 0.77

# %%
df.shape
# Out:
# (6431, 7)

# %% [markdown]
# ## Check VIF score

# %%
df_copy5=df.copy()

# %%
X = df.drop("Weekly_Sales",axis=1)
y = df["Weekly_Sales"]

model = LinearRegression()  
model.fit(X,y)
# Out:
# LinearRegression()

# %%
def multicollinearity_assumption(model, features, label, feature_names=None):
    """
    Multicollinearity: Assumes that predictors are not correlated with each other. If there is
                       correlation among the predictors, then either remove prepdictors with high
                       Variance Inflation Factor (VIF) values or perform dimensionality reduction
                           
                       This assumption being violated causes issues with interpretability of the 
                       coefficients and the standard errors of the coefficients.
    """
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    print('Assumption 2: Little to no multicollinearity among predictors')
        
    # Plotting the heatmap
    plt.figure(figsize = (10,8))
    sns.heatmap(pd.DataFrame(features, columns=feature_names).corr(), annot=True)
    plt.title('Correlation of Variables')
    plt.show()
        
    print('Variance Inflation Factors (VIF)')
    print('> 10: An indication that multicollinearity may be present')
    print('> 100: Certain multicollinearity among the variables')
    print('-------------------------------------')
       
    # Gathering the VIF for each variable
    VIF = [variance_inflation_factor(features, i) for i in range(features.shape[1])]
    for idx, vif in enumerate(VIF):
        print('{0}: {1}'.format(feature_names[idx], vif))
        
    # Gathering and printing total cases of possible or definite multicollinearity
    possible_multicollinearity = sum([1 for vif in VIF if vif > 10])
    definite_multicollinearity = sum([1 for vif in VIF if vif > 100])
    print()
    print('{0} cases of possible multicollinearity'.format(possible_multicollinearity))
    print('{0} cases of definite multicollinearity'.format(definite_multicollinearity))
    print()

    if definite_multicollinearity == 0:
        if possible_multicollinearity == 0:
            print('Assumption satisfied')
        else:
            print('Assumption possibly satisfied')
            print()
            print('Coefficient interpretability may be problematic')
            print('Consider removing variables with a high Variance Inflation Factor (VIF)')

    else:
        print('Assumption not satisfied')
        print()
        print('Coefficient interpretability will be problematic')
        print('Consider removing variables with a high Variance Inflation Factor (VIF)')

# %%
multicollinearity_assumption(model, X, y,X.columns)
# Out:
# Assumption 2: Little to no multicollinearity among predictors
# Variance Inflation Factors (VIF)
# > 10: An indication that multicollinearity may be present
# > 100: Certain multicollinearity among the variables
# -------------------------------------
# Store: 1.082446840151061
# Date: 1.106420347289621
# Holiday_Flag: 1.0273401582051274
# Temperature: 1.1258500912350327
# CPI: 1.1833873030712032
# Unemployment: 1.2608040749253282
#
# 0 cases of possible multicollinearity
# 0 cases of definite multicollinearity
#
# Assumption satisfied

# %% [markdown]
# **After feature selection, 6 features were selected.**

# %% [markdown]
# # Model Selection

# %% [markdown]
# **Selecting appropriate algorithms or methods for analyzing the data, such as regression, decision trees, clustering etc. <br>Model assumptions should be checked to ensure compliance.**

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123, test_size=0.2)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((5144, 6), (5144,), (1287, 6), (1287,))

# %%
model = LinearRegression()  
model.fit(X_train,y_train)  

print(model.score(X_train,y_train))
# Out:
# 0.13986040395802046

# %% [markdown]
# **The model score is too low. Perform Regularization to improve the model score.**

# %% [markdown]
# ### Regularization

# %% [markdown]
# #### Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

y_pred_Ridge = ridge.predict(X_test)
r2_Ridge = r2_score(y_test, y_pred_Ridge)

print("R-squared (Ridge Regression):", r2_Ridge)
# Out:
# R-squared (Ridge Regression): 0.14781699397403114

# %% [markdown]
# #### Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=1.0)
lasso.fit(X_train, y_train)

y_pred_Lasso = lasso.predict(X_test)
r2_Lasso = r2_score(y_test, y_pred_Lasso)
print("R-squared (Lasso Regression):", r2_Lasso)
# Out:
# R-squared (Lasso Regression): -0.00040829019025223623

# %% [markdown]
# **It is seen that the R-squared value has not improved significantly or even has a negative value. <br>
# This may be due to inappropriate selection of the alpha parameter. Adjusting the alpha parameter can improve the regularization effect.**

# %%
alphas = np.linspace(0.01, 10, 100)
ridge_r_squared = []
lasso_r_squared = []

for alpha in alphas:
    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(X_train, y_train)
    y_pred_ridge = ridge_model.predict(X_test)
    ridge_r_squared.append(r2_score(y_test, y_pred_ridge))
    
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train, y_train)
    y_pred_lasso = lasso_model.predict(X_test)
    lasso_r_squared.append(r2_score(y_test, y_pred_lasso))

best_ridge_r_squared = max(ridge_r_squared)
best_ridge_alpha = alphas[ridge_r_squared.index(best_ridge_r_squared)]

best_lasso_r_squared = max(lasso_r_squared)
best_lasso_alpha = alphas[lasso_r_squared.index(best_lasso_r_squared)]

print("Best R-squared (Ridge Regression):", best_ridge_r_squared)
print("Corresponding alpha for Ridge Regression:", best_ridge_alpha)
print("Best R-squared (Lasso Regression):", best_lasso_r_squared)
print("Corresponding alpha for Lasso Regression:", best_lasso_alpha)
# Out:
# Best R-squared (Ridge Regression): 0.14781778211819285
# Corresponding alpha for Ridge Regression: 0.01
# Best R-squared (Lasso Regression): 0.1476180088958361
# Corresponding alpha for Lasso Regression: 0.01

# %% [markdown]
# ### Testing Multiple Linear Regression Assumptions

# %% [markdown]
# #### Linearity Assumption

# %%
def calculate_residuals(model, features, label):
    """
    Creates predictions on the features with the model and calculates residuals
    """
    predictions = model.predict(features)
    df_results = pd.DataFrame({'Actual': label, 'Predicted': predictions})
    df_results['Residuals'] = df_results['Actual'] - df_results['Predicted']
    return df_results

# %%
def linear_assumption(model, features, label):
    """
    Linearity: Assumes that there is a linear relationship between the predictors and
               the response variable. If not, either a quadratic term or another
               algorithm should be used.
    """
    print('Assumption 1: Linear Relationship between the Target and the Feature', '\n')
    # Calculating residuals for the plot
    df_results = calculate_residuals(model, features, label)
  
    print('\nChecking with a scatter plot of actual vs. predicted.',
           'Predictions should follow the diagonal line.')
    
    # Plotting the actual vs predicted values
    fig, ax = plt.subplots(1,2,figsize = (8,4))
    sns.scatterplot(x='Actual', y='Predicted', data=df_results, ax=ax[0], color='b')
    sns.scatterplot(x='Predicted', y='Residuals', data=df_results, ax=ax[1], color='g')
    
    # Plotting the diagonal line
    line_coords = np.arange(df_results.min().min(), df_results.max().max())
    ax[0].plot(line_coords, line_coords, color='darkorange', linestyle='--')
    ax[1].axhline(y=0, color='darkorange', linestyle='--')
    ax[0].set_title('Actual vs. Predicted')
    ax[1].set_title('Predicted vs. Residuals')
    plt.tight_layout()
    plt.show()

# %%
linear_assumption(model, X, y)
# Out:
# Assumption 1: Linear Relationship between the Target and the Feature
#
#
# Checking with a scatter plot of actual vs. predicted. Predictions should follow the diagonal line.

# %% [markdown]
# **There is a linear relationship, meet the linearity assumption.**

# %% [markdown]
# #### No Multicollinearity among Predictors

# %%
def multicollinearity_assumption(model, features, label, feature_names=None):
    """
    Multicollinearity: Assumes that predictors are not correlated with each other. If there is
                       correlation among the predictors, then either remove prepdictors with high
                       Variance Inflation Factor (VIF) values or perform dimensionality reduction
                           
                       This assumption being violated causes issues with interpretability of the 
                       coefficients and the standard errors of the coefficients.
    """
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    print('Assumption 2: Little to no multicollinearity among predictors')
        
    # Plotting the heatmap
    plt.figure(figsize = (10,8))
    sns.heatmap(pd.DataFrame(features, columns=feature_names).corr(), annot=True)
    plt.title('Correlation of Variables')
    plt.show()
        
    print('Variance Inflation Factors (VIF)')
    print('> 10: An indication that multicollinearity may be present')
    print('> 100: Certain multicollinearity among the variables')
    print('-------------------------------------')
       
    # Gathering the VIF for each variable
    VIF = [variance_inflation_factor(features, i) for i in range(features.shape[1])]
    for idx, vif in enumerate(VIF):
        print('{0}: {1}'.format(feature_names[idx], vif))
        
    # Gathering and printing total cases of possible or definite multicollinearity
    possible_multicollinearity = sum([1 for vif in VIF if vif > 10])
    definite_multicollinearity = sum([1 for vif in VIF if vif > 100])
    print()
    print('{0} cases of possible multicollinearity'.format(possible_multicollinearity))
    print('{0} cases of definite multicollinearity'.format(definite_multicollinearity))
    print()

    if definite_multicollinearity == 0:
        if possible_multicollinearity == 0:
            print('Assumption satisfied')
        else:
            print('Assumption possibly satisfied')
            print()
            print('Coefficient interpretability may be problematic')
            print('Consider removing variables with a high Variance Inflation Factor (VIF)')

    else:
        print('Assumption not satisfied')
        print()
        print('Coefficient interpretability will be problematic')
        print('Consider removing variables with a high Variance Inflation Factor (VIF)')

# %%
multicollinearity_assumption(model, X, y,X.columns)
# Out:
# Assumption 2: Little to no multicollinearity among predictors
# Variance Inflation Factors (VIF)
# > 10: An indication that multicollinearity may be present
# > 100: Certain multicollinearity among the variables
# -------------------------------------
# Store: 1.082446840151061
# Date: 1.106420347289621
# Holiday_Flag: 1.0273401582051274
# Temperature: 1.1258500912350327
# CPI: 1.1833873030712032
# Unemployment: 1.2608040749253282
#
# 0 cases of possible multicollinearity
# 0 cases of definite multicollinearity
#
# Assumption satisfied

# %% [markdown]
# #### Normality of the Error Terms

# %%
def normal_errors_assumption(model, features, label, p_value_thresh=0.05):
    """
    Normality: Assumes that the error terms are normally distributed. If they are not,
    nonlinear transformations of variables may solve this.
               
    This assumption being violated primarily causes issues with the confidence intervals
    """
    from statsmodels.stats.diagnostic import normal_ad
    print('Assumption 3: The error terms are normally distributed', '\n')
    
    # Calculating residuals for the Anderson-Darling test
    df_results = calculate_residuals(model, features, label)
    
    print('Using the Anderson-Darling test for normal distribution')

    # Performing the test on the residuals
    p_value = normal_ad(df_results['Residuals'])[1]
    print('p-value from the test - below 0.05 generally means non-normal:', p_value)
    
    # Reporting the normality of the residuals
    if p_value < p_value_thresh:
        print('Residuals are not normally distributed')
    else:
        print('Residuals are normally distributed')
    
    # Plotting the residuals distribution
    plt.subplots(figsize=(12, 6))
    plt.title('Distribution of Residuals')
    sns.distplot(df_results['Residuals'])
    plt.show()
    
    print()
    if p_value > p_value_thresh:
        print('Assumption satisfied')
    else:
        print('Assumption not satisfied')
        print()
        print('Confidence intervals will likely be affected')
        print('Try performing nonlinear transformations on variables')

# %%
normal_errors_assumption(model, X, y)
# Out:
# Assumption 3: The error terms are normally distributed
#
# Using the Anderson-Darling test for normal distribution
# p-value from the test - below 0.05 generally means non-normal: 0.0
# Residuals are not normally distributed
# Assumption not satisfied
#
# Confidence intervals will likely be affected
# Try performing nonlinear transformations on variables

# %% [markdown]
# #### Homoscedasticity

# %%
def homoscedasticity_assumption(model, features, label):
    """
    Homoscedasticity: Assumes that the errors exhibit constant variance
    """
    print('Assumption 4: Homoscedasticity of Error Terms', '\n')
    
    print('Residuals should have relative constant variance')
        
    # Calculating residuals for the plot
    df_results = calculate_residuals(model, features, label)

    # Plotting the residuals
    plt.subplots(figsize=(10, 3))
    ax = plt.subplot(111)  # To remove spines
    """
    These are subplot grid parameters encoded as a single integer. For example, "111" means "1x1 grid, first subplot" and "234" means "2x3 grid, 4th subplot".

    Alternative form for add_subplot(111) is add_subplot(1, 1, 1).
    """
    plt.scatter(x=df_results.index, y=df_results.Residuals, alpha=0.5)
    plt.plot(np.repeat(0, df_results.index.max()), color='darkorange', linestyle='--')
    ax.spines['right'].set_visible(False)  # Removing the right spine
    ax.spines['top'].set_visible(False)  # Removing the top spine
    plt.title('Residuals')
    plt.show()

# %%
homoscedasticity_assumption(model, X, y)
# Out:
# Assumption 4: Homoscedasticity of Error Terms
#
# Residuals should have relative constant variance

# %% [markdown]
# **Generally does not violate homoscedasticity**

# %% [markdown]
# #### No Autocorrelation of the Error Terms

# %%
def autocorrelation_assumption(model, features, label):
    """
    Autocorrelation: Assumes that there is no autocorrelation in the residuals. If there is
                     autocorrelation, then there is a pattern that is not explained due to
                     the current value being dependent on the previous value.
                     This may be resolved by adding a lag variable of either the dependent
                     variable or some of the predictors.
    """
    from statsmodels.stats.stattools import durbin_watson
    print('Assumption 5: No Autocorrelation', '\n')
    
    # Calculating residuals for the Durbin Watson-tests
    df_results = calculate_residuals(model, features, label)

    print('\nPerforming Durbin-Watson Test')
    print('Values of 1.5 < d < 2.5 generally show that there is no autocorrelation in the data')
    print('0 to 2< is positive autocorrelation')
    print('>2 to 4 is negative autocorrelation')
    print('-------------------------------------')
    durbinWatson = durbin_watson(df_results['Residuals'])
    print('Durbin-Watson:', durbinWatson)
    if durbinWatson < 1.5:
        print('Signs of positive autocorrelation', '\n')
        print('Assumption not satisfied')
    elif durbinWatson > 2.5:
        print('Signs of negative autocorrelation', '\n')
        print('Assumption not satisfied')
    else:
        print('Little to no autocorrelation', '\n')
        print('Assumption satisfied')

# %%
autocorrelation_assumption(model, X, y)
# Out:
# Assumption 5: No Autocorrelation
#
#
# Performing Durbin-Watson Test
# Values of 1.5 < d < 2.5 generally show that there is no autocorrelation in the data
# 0 to 2< is positive autocorrelation
# >2 to 4 is negative autocorrelation
# -------------------------------------
# Durbin-Watson: 0.13031047327947481
# Signs of positive autocorrelation
#
# Assumption not satisfied

# %% [markdown]
# **Except for the assumption of no Multicollinearity among predictors, all other assumptions are not satisfied.**

# %% [markdown]
# **Even by adjusting the regularization parameter (alpha), the R-squared value is still relatively low, which may be due to the limitations of the model itself or the complex relationship between the features and the target variable. <br>
# At the same time, the linearity assumption is mostly not satisfied. In this situation consider changing models.**

# %% [markdown]
# ## Decision Tree

# %%
df_copy6=df.copy()

# %%
from sklearn.tree import DecisionTreeRegressor
model_DT = DecisionTreeRegressor(random_state=123)
model_DT.fit(X_train,y_train)

y_pred_DT = model_DT.predict(X_test)
r2_DT = r2_score(y_test, y_pred_DT)
print("R-squared (Decision Tree):", r2_DT)
# Out:
# R-squared (Decision Tree): 0.9098660800628313

# %% [markdown]
# **The score of R-square improved significantly.**

# %%
r2_DT_train = r2_score(y_train, model_DT.predict(X_train))
print("R-squared on Training Set (Decision Tree):", r2_DT_train)
# Out:
# R-squared on Training Set (Decision Tree): 1.0

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model_RF = RandomForestRegressor(random_state=123)
model_RF.fit(X_train,y_train)

y_pred_RF = model_RF.predict(X_test)
r2_RF = r2_score(y_test, y_pred_RF)
print("R-squared (Random Forest):", r2_RF)
# Out:
# R-squared (Random Forest): 0.9480357128740634

# %% [markdown]
# **The score of R-square improved significantly.**

# %%
r2_RF_train = r2_score(y_train, model_RF.predict(X_train))
print("R-squared on Training Set (Random Forest):", r2_RF_train)
# Out:
# R-squared on Training Set (Random Forest): 0.9905329344159012

# %% [markdown]
# **The R-square score of Random Forest is higher than the R-square score of Decision Tree, so the Random Forest model is selected.**

# %% [markdown]
# # Model Training

# %% [markdown]
# **Applying the selected models to the data and allowing them to learn the underlying patterns.**

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
model_RF = RandomForestRegressor(random_state=123)

grid_search = GridSearchCV(model_RF, param_grid, cv=5, n_jobs=-1, verbose=2)

grid_search.fit(X_train, y_train)

best_RF_model = grid_search.best_estimator_
best_params = grid_search.best_params_

print("Best Hyperparameters:", best_params)

y_pred_best = best_RF_model.predict(X_test)

r2_best = r2_score(y_test, y_pred_best)
print("R-squared (Best Random Forest):", r2_best)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# R-squared (Best Random Forest): 0.9508828699102673

# %%
best_random_forest_model = RandomForestRegressor(
    max_depth=None,
    min_samples_leaf=2,
    min_samples_split=2,
    n_estimators=150,
    random_state=123
)

best_RF_model.fit(X_train, y_train)

y_pred_RF = best_RF_model.predict(X_test)

# %%
r2_best = r2_score(y_test, y_pred_RF)
mse = mean_squared_error(y_test, y_pred_RF)
mae = mean_absolute_error(y_test, y_pred_RF)

print("R-squared:", r2_best)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
# Out:
# R-squared: 0.9508828699102673
# Mean Squared Error: 0.04872498108672401
# Mean Absolute Error: 0.11852175207971474

# %% [markdown]
# **The model evaluation results show that the model performs very well on the test set:**<br>
# - R-squared (coefficient of determination) is close to 1, indicating that the model can explain the variance of the target variable well, that is, the model can explain most of the variation in the target variable.
# - The mean squared error (Mean Squared Error) is small, which means that the difference between the model's predicted value and the actual value is small.
# - The Mean Absolute Error is also small, indicating that the absolute difference between the model's predicted values and the actual values is small.<br>
#
# **These evaluation results indicate that this random forest model is quite effective for solving your specific problem.**

# %% [markdown]
# # Pattern Discovery

# %% [markdown]
# **Applying data mining techniques to find interesting and previously unknown patterns, trends, or relationships within the data.**

# %% [markdown]
# **In the EDA step, the outliers of each feature were specifically analyzed. Weekly_Sale has 34 possible outliers, Temperature has 3 possible outliers, and Unemployment has 481 possible outliers and 180 extreme outliers.<br>
# After searching the information online, I found that the unemployment rate has fluctuated between 3% and 15% in the past 20 years. These outliers are within the normal range.<br>
# So I thought they had practical significance and decided to keep them.**

# %% [markdown]
# **After using LOF (Local Outlier Factor), 328 outliers were automatically removed. <br>
# LOF can identify outliers or anomalies in the dataset. The LOF algorithm is a density-based method that takes into account the ratio between the local density of each data point and its own density. When a data point's local density is significantly lower than the average density of its neighboring data points, it is considered an outlier.**

# %% [markdown]
# **In the EDA process, some outliers are valuable and need to be retained, but in the process of building the model, this method of considering the elimination of outliers based on local density is very effective.**

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# **Assessing the performance of the models and the quality of the discovered patterns. <br>This may involve techniques such as cross-validation and measuring various metrics like accuracy, precision, recall, etc.**

# %% [markdown]
# ## Cross validation

# %%
cv_scores = cross_val_score(best_RF_model, X_train, y_train, cv=5, scoring='r2')

print("Cross-Validation R-squared Mean:", cv_scores.mean())
print("Cross-Validation R-squared Standard Deviation:", cv_scores.std())
# Out:
# Cross-Validation R-squared Mean: 0.9321864720438999
# Cross-Validation R-squared Standard Deviation: 0.010714466846583824

# %% [markdown]
# **The average R-squared value is about 0.932, which indicates that this model is able to explain the variance of the target variable well, with about 93.2% of the variance explained by the model.<br>
# The standard deviation is about 0.0107, which means that the range of variation of the cross-validated R-squared value is relatively small and the stability of the model is high.<br>
# These results show that this model performed well in cross-validation, has strong explanatory power for the target variable, and is highly stable, indicating that the model may have good generalization performance.**

# %% [markdown]
# ## Feature Importance

# %%
feature_importances = best_RF_model.feature_importances_
feature_names = list(X.columns)
feature_importances_dict = dict(zip(feature_names, feature_importances))

# %%
plt.figure(figsize=(10, 6))
plt.barh(list(feature_importances_dict.keys()), feature_importances_dict.values())
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance for Random Forest Model')
plt.show()

# %% [markdown]
# # Interpretation and Application

# %% [markdown]
# **Interpreting the results of the analysis and using the insights gained to make informed decisions, predictions, or recommendations.**

# %%
import shap

explainer_RF = shap.Explainer(best_RF_model)

shap_values_RF = explainer_RF.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values_RF, X_test, plot_type="violin", max_display=10)

# %% [markdown]
# **Apply SHAP (SHapley Additive exPlanations) in the Random Forest model to explain model predictions and help us understand the contribution of each feature to model predictions. The SHAP value represents the impact of each feature on a single prediction.**
